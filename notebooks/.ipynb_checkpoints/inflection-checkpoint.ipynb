# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# File to Load

#2020

mar_2020_work = "../work_csv/mar_2020_work.csv"
feb_2020_work = "../work_csv/feb_2020_work.csv"
jan_2020_work = "../work_csv/jan_2020_work.csv"

#2019
dec_2019_work = "../work_csv/dec_2019_work.csv"
nov_2019_work = "../work_csv/nov_2019_work.csv"
oct_2019_work = "../work_csv/oct_2019_work.csv"
sep_2019_work = "../work_csv/sep_2019_work.csv"
aug_2019_work = "../work_csv/aug_2019_work.csv"
jul_2019_work = "../work_csv/jul_2019_work.csv"
jun_2019_work = "../work_csv/jun_2019_work.csv"
may_2019_work = "../work_csv/may_2019_work.csv"
apr_2019_work = "../work_csv/apr_2019_work.csv"
mar_2019_work = "../work_csv/mar_2019_work.csv"
feb_2019_work = "../work_csv/feb_2019_work.csv"
jan_2019_work = "../work_csv/jan_2019_work.csv"

#2018
dec_2018_work = "../work_csv/dec_2018_work.csv"
nov_2018_work = "../work_csv/nov_2018_work.csv"
oct_2018_work = "../work_csv/oct_2018_work.csv"
sep_2018_work = "../work_csv/sep_2018_work.csv"
aug_2018_work = "../work_csv/aug_2018_work.csv"
jul_2018_work = "../work_csv/jul_2018_work.csv"
jun_2018_work = "../work_csv/jun_2018_work.csv"
may_2018_work = "../work_csv/may_2018_work.csv"
apr_2018_work = "../work_csv/apr_2018_work.csv"
mar_2018_work = "../work_csv/mar_2018_work.csv"
feb_2018_work = "../work_csv/feb_2018_work.csv"
jan_2018_work = "../work_csv/jan_2018_work.csv"

#2017
dec_2017_work = "../work_csv/dec_2017_work.csv"
nov_2017_work = "../work_csv/nov_2017_work.csv"
oct_2017_work = "../work_csv/oct_2017_work.csv"
sep_2017_work = "../work_csv/sep_2017_work.csv"
aug_2017_work = "../work_csv/aug_2017_work.csv"
jul_2017_work = "../work_csv/jul_2017_work.csv"
jun_2017_work = "../work_csv/jun_2017_work.csv"
may_2017_work = "../work_csv/may_2017_work.csv"
apr_2017_work = "../work_csv/apr_2017_work.csv"
mar_2017_work = "../work_csv/mar_2017_work.csv"

# Read Purchasing File and store into Pandas data frame
mar_2020 = pd.read_csv(mar_2020_work, low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
feb_2020 = pd.read_csv(feb_2020_work, low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jan_2020 = pd.read_csv(jan_2020_work, low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})

#mar_2020["price"] = mar_2020["price"].str.replace(',', '')
#mar_2020["price"] = mar_2020["price"].str.replace('$', '')

#feb_2020["price"] = feb_2020["price"].str.replace(',', '')
#feb_2020["price"] = feb_2020["price"].str.replace('$', '')

#jan_2020["price"] = jan_2020["price"].str.replace(',', '')
#jan_2020["price"] = jan_2020["price"].str.replace('$', '')

dec_2019 = pd.read_csv(dec_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
nov_2019 = pd.read_csv(nov_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
oct_2019 = pd.read_csv(oct_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
sep_2019 = pd.read_csv(sep_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
aug_2019 = pd.read_csv(aug_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jul_2019 = pd.read_csv(jul_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jun_2019 = pd.read_csv(jun_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
may_2019 = pd.read_csv(may_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
apr_2019 = pd.read_csv(apr_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
mar_2019 = pd.read_csv(mar_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
feb_2019 = pd.read_csv(feb_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jan_2019 = pd.read_csv(jan_2019_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})

dec_2018 = pd.read_csv(dec_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
nov_2018 = pd.read_csv(nov_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
oct_2018 = pd.read_csv(oct_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
sep_2018 = pd.read_csv(sep_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
aug_2018 = pd.read_csv(aug_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jul_2018 = pd.read_csv(jul_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jun_2018 = pd.read_csv(jun_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
may_2018 = pd.read_csv(may_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
apr_2018 = pd.read_csv(apr_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
mar_2018 = pd.read_csv(mar_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
feb_2018 = pd.read_csv(feb_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jan_2018 = pd.read_csv(jan_2018_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})

dec_2017 = pd.read_csv(dec_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
nov_2017 = pd.read_csv(nov_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
oct_2017 = pd.read_csv(oct_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
sep_2017 = pd.read_csv(sep_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
aug_2017 = pd.read_csv(aug_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jul_2017 = pd.read_csv(jul_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
jun_2017 = pd.read_csv(jun_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
may_2017 = pd.read_csv(may_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
apr_2017 = pd.read_csv(apr_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})
mar_2017 = pd.read_csv(mar_2017_work,low_memory=False, sep="\t",  
                 dtype={'host_is_superhost': bool,'host_identity_verified': bool, 'is_location_exact': bool})

#2020
#combo_2020 = pd.merge(mar_2020, feb_2020, jan_2020, on="host_id")
#combo_2020.head()

#jan_2020.append(feb_2020)

#combo_2020 = pd.merge(mar_2020, feb_2020, on='id', how='outer', indicator='True')
#combo_2020.head()

march_2020 = mar_2020[["id", "host_is_superhost", "neighbourhood_group_cleansed", "latitude", "longitude", "property_type", "room_type", "price"]]
march_2020
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-fb598480c6d8> in <module>
#     155 #combo_2020.head()
#     156
# --> 157 march_2020 = mar_2020[["id", "host_is_superhost", "neighbourhood_group_cleansed", "latitude", "longitude", "property_type", "room_type", "price"]]
#     158 march_2020
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
march_2019_small = march_2019[["id", "host_is_superhost", "neighbourhood_group_cleansed", "latitude", "longitude", "property_type", "room_type", "price"]]
march_2019_small
